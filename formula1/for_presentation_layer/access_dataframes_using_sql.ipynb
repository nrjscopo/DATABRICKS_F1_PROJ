# %%
# %run "../Includes/configurations"

# %%
race_results=spark.read.parquet(f"{presentation_folder_path}/race_results")

# %%
# race_results.createTempView("v_race_results")
# race_results.createGlobalTempView("gv_race_results")

# %%
# %sql

select count(*) from v_race_results
where year=2020
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>340</td></tr></tbody></table></div>

# %%
# %sql  show tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td></td><td>_sqldf</td><td>true</td></tr><tr><td></td><td>gv_race_results</td><td>true</td></tr><tr><td></td><td>v_race_results</td><td>true</td></tr></tbody></table></div>

# %%
race_results.createOrReplaceGlobalTempView("gv_race_results")

# %%
# %sql  show tables in global_temp
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>global_temp</td><td>gv_race_results</td><td>true</td></tr><tr><td></td><td>_sqldf</td><td>true</td></tr><tr><td></td><td>gv_race_results</td><td>true</td></tr><tr><td></td><td>v_race_results</td><td>true</td></tr></tbody></table></div>
